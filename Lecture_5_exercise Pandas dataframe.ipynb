# %% [markdown]
# <a href="https://colab.research.google.com/github/chiwangchic/hello-world/blob/master/Lecture_5_exercise%20Pandas%20dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#First upload the nba.csv 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5c498441-8810-4b01-beae-aa8f3629bb7a" name="files[]" multiple disabled />
#      <output id="result-5c498441-8810-4b01-beae-aa8f3629bb7a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nba.csv to nba (1).csv

# %%
import pandas as pd

data = pd.read_csv("nba.csv")

print(data["College"])

data["College"].fillna("No College", inplace = True) 

print(data["College"])
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                    NaN
# 5                    NaN
# 6                    LSU
# 7                Gonzaga
# 8             Louisville
# 9         Oklahoma State
# 10            Ohio State
# 11            Washington
# 12            Ohio State
# 13              Kentucky
# 14        North Carolina
# 15                   NaN
# 16        Oklahoma State
# 17        North Carolina
# 18               Arizona
# 19          Georgia Tech
# 20                   NaN
# 21            Cincinnati
# 22            Miami (FL)
# 23              Stanford
# 24              Syracuse
# 25           Saint Louis
# 26                Kansas
# 27            Georgetown
# 28             Texas A&M
# 29          Georgia Tech
#              ...
# 428          Wake Forest
# 429           Notre Dame
# 430           California
# 431       North Carolina
# 432           St. John's
# 433                 Duke
# ...

# %%
import pandas as pd
data = pd.read_csv("nba.csv")

print(data["College"])
data["College"].fillna(method="ffill", inplace=True)

print(data["College"])
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                    NaN
# 5                    NaN
# 6                    LSU
# 7                Gonzaga
# 8             Louisville
# 9         Oklahoma State
# 10            Ohio State
# 11            Washington
# 12            Ohio State
# 13              Kentucky
# 14        North Carolina
# 15                   NaN
# 16        Oklahoma State
# 17        North Carolina
# 18               Arizona
# 19          Georgia Tech
# 20                   NaN
# 21            Cincinnati
# 22            Miami (FL)
# 23              Stanford
# 24              Syracuse
# 25           Saint Louis
# 26                Kansas
# 27            Georgetown
# 28             Texas A&M
# 29          Georgia Tech
#              ...
# 428          Wake Forest
# 429           Notre Dame
# 430           California
# 431       North Carolina
# 432           St. John's
# 433                 Duke
# ...

# %%
import pandas as pd
data = pd.read_csv("nba.csv")

print(data["College"])
data["College"].fillna(method="bfill", inplace=True)

print(data["College"])
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                    NaN
# 5                    NaN
# 6                    LSU
# 7                Gonzaga
# 8             Louisville
# 9         Oklahoma State
# 10            Ohio State
# 11            Washington
# 12            Ohio State
# 13              Kentucky
# 14        North Carolina
# 15                   NaN
# 16        Oklahoma State
# 17        North Carolina
# 18               Arizona
# 19          Georgia Tech
# 20                   NaN
# 21            Cincinnati
# 22            Miami (FL)
# 23              Stanford
# 24              Syracuse
# 25           Saint Louis
# 26                Kansas
# 27            Georgetown
# 28             Texas A&M
# 29          Georgia Tech
#              ...
# 428          Wake Forest
# 429           Notre Dame
# 430           California
# 431       North Carolina
# 432           St. John's
# 433                 Duke
# ...

# %%
import pandas as pd 
  
data = pd.read_csv("nba.csv") 
  
print(data["College"])
data["College"].fillna( method ='ffill', limit = 1, inplace = True) 
  
print(data["College"])
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                    NaN
# 5                    NaN
# 6                    LSU
# 7                Gonzaga
# 8             Louisville
# 9         Oklahoma State
# 10            Ohio State
# 11            Washington
# 12            Ohio State
# 13              Kentucky
# 14        North Carolina
# 15                   NaN
# 16        Oklahoma State
# 17        North Carolina
# 18               Arizona
# 19          Georgia Tech
# 20                   NaN
# 21            Cincinnati
# 22            Miami (FL)
# 23              Stanford
# 24              Syracuse
# 25           Saint Louis
# 26                Kansas
# 27            Georgetown
# 28             Texas A&M
# 29          Georgia Tech
#              ...
# 428          Wake Forest
# 429           Notre Dame
# 430           California
# 431       North Carolina
# 432           St. John's
# 433                 Duke
# ...

# %%
import pandas as pd 
  
data = pd.read_csv("nba.csv") 
  
bool_series = pd.isnull(data["College"]) 
  
# filtering data 
# displayind data only with players's college = NaN 
data[bool_series]
# Out:
#                        Name                    Team  ...  College      Salary
# 4             Jonas Jerebko          Boston Celtics  ...      NaN   5000000.0
# 5              Amir Johnson          Boston Celtics  ...      NaN  12000000.0
# 15         Bojan Bogdanovic           Brooklyn Nets  ...      NaN   3425510.0
# 20           Sergey Karasev           Brooklyn Nets  ...      NaN   1599840.0
# 32   Thanasis Antetokounmpo         New York Knicks  ...      NaN     30888.0
# 34            Jose Calderon         New York Knicks  ...      NaN   7402812.0
# 40       Kristaps Porzingis         New York Knicks  ...      NaN   4131720.0
# 41           Kevin Seraphin         New York Knicks  ...      NaN   2814000.0
# 43            Sasha Vujacic         New York Knicks  ...      NaN    947276.0
# 61          Bismack Biyombo         Toronto Raptors  ...      NaN   2814000.0
# 62            Bruno Caboclo         Toronto Raptors  ...      NaN   1524000.0
# ...

# %%
import pandas as pd 
  
data = pd.read_csv("nba.csv") 
  
bool_series = pd.notnull(data["College"]) 

data[bool_series]
# Out:
#                         Name  ...      Salary
# 0              Avery Bradley  ...   7730337.0
# 1                Jae Crowder  ...   6796117.0
# 2               John Holland  ...         NaN
# 3                R.J. Hunter  ...   1148640.0
# 6              Jordan Mickey  ...   1170960.0
# 7               Kelly Olynyk  ...   2165160.0
# 8               Terry Rozier  ...   1824360.0
# 9               Marcus Smart  ...   3431040.0
# 10           Jared Sullinger  ...   2569260.0
# 11             Isaiah Thomas  ...   6912869.0
# 12               Evan Turner  ...   3425510.0
# 13               James Young  ...   1749840.0
# 14              Tyler Zeller  ...   2616975.0
# 16              Markel Brown  ...    845059.0
# 17           Wayne Ellington  ...   1500000.0
# 18   Rondae Hollis-Jefferson  ...   1335480.0
# 19              Jarrett Jack  ...   6300000.0
# 21           Sean Kilpatrick  ...    134215.0
# 22              Shane Larkin  ...   1500000.0
# ...

# %%
import pandas as pd 

data = pd.read_csv("nba.csv")

print(data)

gbc = data.groupby("Team")

print(gbc.first())
# Out:
#                         Name  ...      Salary
# 0              Avery Bradley  ...   7730337.0
# 1                Jae Crowder  ...   6796117.0
# 2               John Holland  ...         NaN
# 3                R.J. Hunter  ...   1148640.0
# 4              Jonas Jerebko  ...   5000000.0
# 5               Amir Johnson  ...  12000000.0
# 6              Jordan Mickey  ...   1170960.0
# 7               Kelly Olynyk  ...   2165160.0
# 8               Terry Rozier  ...   1824360.0
# 9               Marcus Smart  ...   3431040.0
# 10           Jared Sullinger  ...   2569260.0
# 11             Isaiah Thomas  ...   6912869.0
# 12               Evan Turner  ...   3425510.0
# 13               James Young  ...   1749840.0
# 14              Tyler Zeller  ...   2616975.0
# 15          Bojan Bogdanovic  ...   3425510.0
# 16              Markel Brown  ...    845059.0
# 17           Wayne Ellington  ...   1500000.0
# 18   Rondae Hollis-Jefferson  ...   1335480.0
# ...

# %%
print(gbc.get_group('Golden State Warriors'))
# Out:
#                     Name  Number Position  ...  Weight           College      Salary
# 76       Leandro Barbosa    19.0       SG  ...   194.0               NaN   2500000.0
# 77       Harrison Barnes    40.0       SF  ...   225.0    North Carolina   3873398.0
# 78          Andrew Bogut    12.0        C  ...   260.0              Utah  13800000.0
# 79             Ian Clark    21.0       SG  ...   175.0           Belmont    947276.0
# 80         Stephen Curry    30.0       PG  ...   190.0          Davidson  11370786.0
# 81          Festus Ezeli    31.0        C  ...   265.0        Vanderbilt   2008748.0
# 82        Draymond Green    23.0       PF  ...   230.0    Michigan State  14260870.0
# 83        Andre Iguodala     9.0       SF  ...   215.0           Arizona  11710456.0
# 84      Shaun Livingston    34.0       PG  ...   192.0               NaN   5543725.0
# 85          Kevon Looney    36.0       SF  ...   220.0              UCLA   1131960.0
# ...

# %%
import pandas as pd 

data = pd.read_csv("nba.csv")

gbc = data.groupby(["Team", "Position"])

print(gbc.first())
# Out:
#                                                    Name  ...      Salary
# Team                   Position                          ...
# Atlanta Hawks          C                     Al Horford  ...  12000000.0
#                        PF                Kris Humphries  ...   1000000.0
#                        PG               Dennis Schroder  ...   1763400.0
#                        SF                 Kent Bazemore  ...   2000000.0
#                        SG              Tim Hardaway Jr.  ...   1304520.0
# Boston Celtics         C                   Kelly Olynyk  ...   2165160.0
#                        PF                 Jonas Jerebko  ...   5000000.0
#                        PG                 Avery Bradley  ...   7730337.0
#                        SF                   Jae Crowder  ...   6796117.0
#                        SG                  John Holland  ...   1148640.0
# Brooklyn Nets          C                    Brook Lopez  ...  19689000.0
# ...

# %%
import pandas as pd 

data = pd.read_csv("nba.csv")

gbc = data.groupby(["Team", "Position"])

print(gbc.get_group(("Golden State Warriors","PG")))
# Out:
#                 Name                   Team  ...   College      Salary
# 80     Stephen Curry  Golden State Warriors  ...  Davidson  11370786.0
# 84  Shaun Livingston  Golden State Warriors  ...       NaN   5543725.0
#
# [2 rows x 9 columns]

# %%
# !wget https://raw.githubusercontent.com/rpi-techfundamentals/spring2019-materials/master/input/train.csv
# !wget https://raw.githubusercontent.com/rpi-techfundamentals/spring2019-materials/master/input/test.csv
# Out:
# --2019-10-13 03:45:00--  https://raw.githubusercontent.com/rpi-techfundamentals/spring2019-materials/master/input/train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61194 (60K) [text/plain]
# Saving to: ‘train.csv’
#
# train.csv           100%[===================>]  59.76K  --.-KB/s    in 0.02s
#
# 2019-10-13 03:45:00 (2.34 MB/s) - ‘train.csv’ saved [61194/61194]
#
# --2019-10-13 03:45:01--  https://raw.githubusercontent.com/rpi-techfundamentals/spring2019-materials/master/input/test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# ...

# %%
from google.colab import files
files.download('train.csv')
files.download('test.csv')

# %%
import numpy as np 
import pandas as pd 


train = pd.read_csv("train.csv")
test  = pd.read_csv("test.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
test.head()
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
#Creating a test dataset

test["Survived"] = 0

print(test.head())

submission = test.loc[:,["PassengerId", "Survived"]]

submission.to_csv('everyone_dies.csv', index=False)
# Out:
#    PassengerId  Pclass  ... Embarked Survived
# 0          892       3  ...        Q        0
# 1          893       3  ...        S        0
# 2          894       2  ...        Q        0
# 3          895       3  ...        S        0
# 4          896       3  ...        S        0
#
# [5 rows x 12 columns]

# %%
from google.colab import files
files.download('everyone_dies.csv')

# %%
test.loc[test['Sex'] == 'male', 'PredGender'] = 0
test.loc[test['Sex'] == 'female', 'PredGender'] = 1

test
# Out:
#      PassengerId  Pclass  ... Survived PredGender
# 0            892       3  ...        0        0.0
# 1            893       3  ...        0        1.0
# 2            894       2  ...        0        0.0
# 3            895       3  ...        0        0.0
# 4            896       3  ...        0        1.0
# 5            897       3  ...        0        0.0
# 6            898       3  ...        0        1.0
# 7            899       2  ...        0        0.0
# 8            900       3  ...        0        1.0
# 9            901       3  ...        0        0.0
# 10           902       3  ...        0        0.0
# 11           903       1  ...        0        0.0
# 12           904       1  ...        0        1.0
# 13           905       2  ...        0        0.0
# 14           906       1  ...        0        1.0
# 15           907       2  ...        0        1.0
# 16           908       2  ...        0        0.0
# 17           909       3  ...        0        0.0
# ...

# %%
submission = test.loc[:,['PassengerId', 'PredGender']]
submission.head()
# Out:
#    PassengerId  PredGender
# 0          892         0.0
# 1          893         1.0
# 2          894         0.0
# 3          895         0.0
# 4          896         1.0

# %%
submission.rename(columns={'PredGender': 'Survived'}, inplace=True)
submission.head()
# Out:
#    PassengerId  Survived
# 0          892       0.0
# 1          893       1.0
# 2          894       0.0
# 3          895       0.0
# 4          896       1.0

# %%
submission.to_csv('women_survive.csv', index=False)
from google.colab import files
files.download('women_survive.csv')

# %%
test.head()
# Out:
#    PassengerId  Pclass  ... Survived PredGender
# 0          892       3  ...        0        0.0
# 1          893       3  ...        0        1.0
# 2          894       2  ...        0        0.0
# 3          895       3  ...        0        0.0
# 4          896       3  ...        0        1.0
#
# [5 rows x 13 columns]

# %%
matched = (test["PredGender"]==test["Survived"])

print(test[matched])
mat=len(test[matched].index)

print(mat)
# Out:
#      PassengerId  Pclass  ... Survived PredGender
# 0            892       3  ...        0        0.0
# 2            894       2  ...        0        0.0
# 3            895       3  ...        0        0.0
# 5            897       3  ...        0        0.0
# 7            899       2  ...        0        0.0
# 9            901       3  ...        0        0.0
# 10           902       3  ...        0        0.0
# 11           903       1  ...        0        0.0
# 13           905       2  ...        0        0.0
# 16           908       2  ...        0        0.0
# 17           909       3  ...        0        0.0
# 20           912       1  ...        0        0.0
# 21           913       3  ...        0        0.0
# 23           915       1  ...        0        0.0
# 25           917       3  ...        0        0.0
# 27           919       3  ...        0        0.0
# 28           920       1  ...        0        0.0
# 29           921       3  ...        0        0.0
# ...

# %%
unmatched = (test["PredGender"]!=test["Survived"])

print(test[unmatched])
unmat=len(test[unmatched].index)

print(unmat)
# Out:
#      PassengerId  Pclass  ... Survived PredGender
# 1            893       3  ...        0        1.0
# 4            896       3  ...        0        1.0
# 6            898       3  ...        0        1.0
# 8            900       3  ...        0        1.0
# 12           904       1  ...        0        1.0
# 14           906       1  ...        0        1.0
# 15           907       2  ...        0        1.0
# 18           910       3  ...        0        1.0
# 19           911       3  ...        0        1.0
# 22           914       1  ...        0        1.0
# 24           916       1  ...        0        1.0
# 26           918       1  ...        0        1.0
# 32           924       3  ...        0        1.0
# 33           925       3  ...        0        1.0
# 36           928       3  ...        0        1.0
# 37           929       3  ...        0        1.0
# 43           935       2  ...        0        1.0
# 44           936       1  ...        0        1.0
# ...

# %%
accuracy = str(round((mat*1.0)/(mat+unmat), 2))

print(accuracy)
# Out:
# 0.64
